# %%
import pandas as pd 
exam = pd.read_csv('exam.csv')
exam
# Out:
#     id  nclass  front  back  design
# 0    1       1     50    98      50
# 1    2       1     60    97      60
# 2    3       1     45    86      78
# 3    4       1     30    98      58
# 4    5       2     25    80      65
# 5    6       2     50    89      98
# 6    7       2     80    90      45
# 7    8       2     90    78      25
# 8    9       3     20    98      15
# 9   10       3     50    98      45
# 10  11       3     65    65      65
# 11  12       3     45    85      32
# 12  13       4     46    98      65
# 13  14       4     48    87      12
# 14  15       4     75    56      78
# 15  16       4     58    98      65
# 16  17       5     65    68      98
# 17  18       5     80    78      90
# 18  19       5     89    68      87
# 19  20       5     78    83      58

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 10.8 MB 2.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.3 MB 2.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 347 kB 2.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 509 kB 2.1 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
exam.query('nclass == 1')
# Out:
#    id  nclass  front  back  design
# 0   1       1     50    98      50
# 1   2       1     60    97      60
# 2   3       1     45    86      78
# 3   4       1     30    98      58

# %%
exam.query('nclass != 1')
# Out:
#     id  nclass  front  back  design
# 4    5       2     25    80      65
# 5    6       2     50    89      98
# 6    7       2     80    90      45
# 7    8       2     90    78      25
# 8    9       3     20    98      15
# 9   10       3     50    98      45
# 10  11       3     65    65      65
# 11  12       3     45    85      32
# 12  13       4     46    98      65
# 13  14       4     48    87      12
# 14  15       4     75    56      78
# 15  16       4     58    98      65
# 16  17       5     65    68      98
# 17  18       5     80    78      90
# 18  19       5     89    68      87
# 19  20       5     78    83      58

# %%
exam.query("front > 50")
# Out:
#     id  nclass  front  back  design
# 1    2       1     60    97      60
# 6    7       2     80    90      45
# 7    8       2     90    78      25
# 10  11       3     65    65      65
# 14  15       4     75    56      78
# 15  16       4     58    98      65
# 16  17       5     65    68      98
# 17  18       5     80    78      90
# 18  19       5     89    68      87
# 19  20       5     78    83      58

# %%
exam.query('front <50')
# Out:
#     id  nclass  front  back  design
# 2    3       1     45    86      78
# 3    4       1     30    98      58
# 4    5       2     25    80      65
# 8    9       3     20    98      15
# 11  12       3     45    85      32
# 12  13       4     46    98      65
# 13  14       4     48    87      12

# %%
exam.query('back >= 50')
# Out:
#     id  nclass  front  back  design
# 0    1       1     50    98      50
# 1    2       1     60    97      60
# 2    3       1     45    86      78
# 3    4       1     30    98      58
# 4    5       2     25    80      65
# 5    6       2     50    89      98
# 6    7       2     80    90      45
# 7    8       2     90    78      25
# 8    9       3     20    98      15
# 9   10       3     50    98      45
# 10  11       3     65    65      65
# 11  12       3     45    85      32
# 12  13       4     46    98      65
# 13  14       4     48    87      12
# 14  15       4     75    56      78
# 15  16       4     58    98      65
# 16  17       5     65    68      98
# 17  18       5     80    78      90
# 18  19       5     89    68      87
# 19  20       5     78    83      58

# %%
exam.query('back >=50')
# Out:
#     id  nclass  front  back  design
# 0    1       1     50    98      50
# 1    2       1     60    97      60
# 2    3       1     45    86      78
# 3    4       1     30    98      58
# 4    5       2     25    80      65
# 5    6       2     50    89      98
# 6    7       2     80    90      45
# 7    8       2     90    78      25
# 8    9       3     20    98      15
# 9   10       3     50    98      45
# 10  11       3     65    65      65
# 11  12       3     45    85      32
# 12  13       4     46    98      65
# 13  14       4     48    87      12
# 14  15       4     75    56      78
# 15  16       4     58    98      65
# 16  17       5     65    68      98
# 17  18       5     80    78      90
# 18  19       5     89    68      87
# 19  20       5     78    83      58

# %%
exam.query('back <= 80')
# Out:
#     id  nclass  front  back  design
# 4    5       2     25    80      65
# 7    8       2     90    78      25
# 10  11       3     65    65      65
# 14  15       4     75    56      78
# 16  17       5     65    68      98
# 17  18       5     80    78      90
# 18  19       5     89    68      87

# %%
exam.query('nclass == 1 & front >= 50')
# Out:
#    id  nclass  front  back  design
# 0   1       1     50    98      50
# 1   2       1     60    97      60

# %%
exam.query('front >= 90 | back >= 90')
# Out:
#     id  nclass  front  back  design
# 0    1       1     50    98      50
# 1    2       1     60    97      60
# 3    4       1     30    98      58
# 6    7       2     80    90      45
# 7    8       2     90    78      25
# 8    9       3     20    98      15
# 9   10       3     50    98      45
# 12  13       4     46    98      65
# 15  16       4     58    98      65

# %%
exam.query('nclass == 1 | nclass == 3 | nclass== 5')
# Out:
#     id  nclass  front  back  design
# 0    1       1     50    98      50
# 1    2       1     60    97      60
# 2    3       1     45    86      78
# 3    4       1     30    98      58
# 8    9       3     20    98      15
# 9   10       3     50    98      45
# 10  11       3     65    65      65
# 11  12       3     45    85      32
# 16  17       5     65    68      98
# 17  18       5     80    78      90
# 18  19       5     89    68      87
# 19  20       5     78    83      58

# %%
exam.query('nclass in [1,3,5]')
# Out:
#     id  nclass  front  back  design
# 0    1       1     50    98      50
# 1    2       1     60    97      60
# 2    3       1     45    86      78
# 3    4       1     30    98      58
# 8    9       3     20    98      15
# 9   10       3     50    98      45
# 10  11       3     65    65      65
# 11  12       3     45    85      32
# 16  17       5     65    68      98
# 17  18       5     80    78      90
# 18  19       5     89    68      87
# 19  20       5     78    83      58

# %%
nclass1 = exam.query('nclasss == 1')
nclass2 = exam.query('nclasss == 2')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/collections/__init__.py:941, in ChainMap.__getitem__(self, key)
#     940         pass
# --> 941 return self.__missing__(key)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/collections/__init__.py:933, in ChainMap.__missing__(self, key)
#     932 def __missing__(self, key):
# --> 933     raise KeyError(key)
#
# KeyError: 'nclasss'
#
# ...
